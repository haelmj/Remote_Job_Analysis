# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_path = 'C:/Users/manj1/Documents/projects/Remote_Job_Analysis/Stage1-DataGathering/data.csv'
df = pd.read_csv(data_path)
df.describe()
# Out:
#        company                    title   job-type  \
# count     1012                     1012       1012
# unique     624                      855          2
# top     TaxJar  Senior Product Designer  Full-Time
# freq        19                       13        909
#
#                      company-region     category
# count                           986         1012
# unique                            8            8
# top     Anywhere (100% Remote) Only  Programming
# freq                            527          492

# %%
df.isna().sum()
# Out:
# company            0
# title              0
# job-type           0
# company-region    26
# category           0
# dtype: int64

# %%
df['company-region'].fillna('Anywhere (100% Remote) Only', inplace=True)

# %%
df
# Out:
#                company                                   title   job-type  \
# 0              Contra                 Senior Product Designer    Contract
# 1         Aurora Solar                 Senior Product Designer  Full-Time
# 2             InDebted                 Senior Product Designer  Full-Time
# 3            Speechify              Senior UI/Systems Designer  Full-Time
# 4               TaxJar                 Senior Product Designer  Full-Time
# ...                ...                                     ...        ...
# 1007            Shogun           Senior Product Manager - DevX  Full-Time
# 1008            Grayce                         Product Manager  Full-Time
# 1009         Silverfin               Technical Product Manager  Full-Time
# 1010          Catch Co  Conversion Rate Optimization Associate  Full-Time
# 1011  We Make Websites     Product Owner (Shopify Agency) - UK  Full-Time
#
#                    company-region category
# 0     Anywhere (100% Remote) Only   Design
# 1              North America Only   Design
# 2     Anywhere (100% Remote) Only   Design
# 3              North America Only   Design
# 4                        USA Only   Design
# ...                           ...      ...
# 1007           North America Only  Product
# 1008                     USA Only  Product
# 1009  Anywhere (100% Remote) Only  Product
# 1010                     USA Only  Product
# 1011                  Europe Only  Product
#
# [1012 rows x 5 columns]

# %% [markdown]
# How entries are there for each category? Show plot

# %% [markdown]
# Show agrregations based on company-region
